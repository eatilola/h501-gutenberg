# %%
# !conda env list
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
# base                     C:\Users\atilo\miniconda3
# h501-gutenberg       *   C:\Users\atilo\miniconda3\envs\h501-gutenberg
# student-performance      C:\Users\atilo\miniconda3\envs\student-performance
# week-3                   C:\Users\atilo\miniconda3\envs\week-3

# %%
import pandas as pandas

import pydytuesday

# Download files from the week, which you can then read in locally
pydytuesday.get_date('2025-06-03')

# Option 2: Read directly from GitHub and assign to an object

gutenberg_authors = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-06-03/gutenberg_authors.csv')
gutenberg_languages = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-06-03/gutenberg_languages.csv')
gutenberg_metadata = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-06-03/gutenberg_metadata.csv')
gutenberg_subjects = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-06-03/gutenberg_subjects.csv')
# Out:
# Trying to fetch README from: https://raw.githubusercontent.com/rfordatascience/tidytuesday/refs/heads/main/data/2025/2025-06-03/readme.md
# Successfully fetched README from: https://raw.githubusercontent.com/rfordatascience/tidytuesday/refs/heads/main/data/2025/2025-06-03/readme.md
# Downloading gutenberg_authors.csv...
# Successfully saved gutenberg_authors.csv to c:\Users\atilo\OneDrive\Desktop\Projects\h501-gutenberg\gutenberg_authors.csv
# Downloading gutenberg_languages.csv...
# Successfully saved gutenberg_languages.csv to c:\Users\atilo\OneDrive\Desktop\Projects\h501-gutenberg\gutenberg_languages.csv
# Downloading gutenberg_metadata.csv...
# Successfully saved gutenberg_metadata.csv to c:\Users\atilo\OneDrive\Desktop\Projects\h501-gutenberg\gutenberg_metadata.csv
# Downloading gutenberg_subjects.csv...
# Successfully saved gutenberg_subjects.csv to c:\Users\atilo\OneDrive\Desktop\Projects\h501-gutenberg\gutenberg_subjects.csv
# Downloading meta.yaml...
# Successfully saved meta.yaml to c:\Users\atilo\OneDrive\Desktop\Projects\h501-gutenberg\meta.yaml
# Downloading pg-logo-129x80.png...
# Successfully saved pg-logo-129x80.png to c:\Users\atilo\OneDrive\Desktop\Projects\h501-gutenberg\pg-logo-129x80.png

# %%
from tt_gutenberg.authors import *

list_authors(by_languages=True, alias=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from tt_gutenberg.authors import *
#       3 list_authors(by_languages=True, alias=True)
#
# ModuleNotFoundError: No module named 'tt_gutenberg'
